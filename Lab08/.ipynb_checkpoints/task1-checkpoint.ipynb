# %%
import numpy as np
from sklearn import linear_model
import sklearn.model_selection as mdsl
from sklearn.model_selection import cross_validate
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-33-41e7f35b3d71> in <module>()
#       2 from sklearn import linear_model
#       3 import sklearn.model_selection as mdsl
# ----> 4 from sklearn.model_selection import cross_validate
#
# ImportError: cannot import name 'cross_validate'

# %%
data = np.loadtxt("ds-boot-1.csv", delimiter='\t', skiprows=1)

# %%
data2 = np.loadtxt("ds-boot-2.csv", delimiter='\t', skiprows=1)

# %%
def bstrapped_param(p_func, sample, B):
    n = sample.size
    strapped_samples = np.random.choice(sample, (B,n))
#     print(np.apply_along_axis(p_func, 1, strapped_samples).shape)
#     print(np.apply_along_axis(p_func, 1, strapped_samples))
    strapped_params = np.apply_along_axis(p_func, 1, strapped_samples)
    strp_params_mean = strapped_params.mean()
    strp_params_std = strapped_params.std()
    print('Evaluated parameter is {:.3f}\nIts MSE is {:.3f}'.format(strp_params_mean, strp_params_std))
#     print(np.mean(strapped_samples[1,:]))

# %%
B=5000

# %%
bstrapped_param(np.median, data2[:,-3], B)
# Out:
# Evaluated parameter is 8.303
# Its MSE is 0.276

# %%
def create_B_sample_indices(dataset, B):
    m = dataset.shape[0]
    n = dataset.shape[1]
    result_indices = np.random.choice(m, (B,m))
    return result_indices

# %%
def train_B_regressions(dataset, B):
    indices_2d = create_B_sample_indices(dataset,B)
    m = dataset.shape[0]
    n = dataset.shape[1]-6
    result = np.empty((B,5,n))
#     sigmas  = np.empty(B)
    regr = linear_model.LinearRegression()
    i=0
    for line in indices_2d:
#         print(line)
#         print(dataset[line][:,1:-5].shape)
        regr.fit(dataset[line][:,1:-5], dataset[line][:,-5:])
        coefs = regr.coef_
#         print(coefs.shape)
        result[i] = coefs
#         sigmas[i] = np.std(regr.predict(dataset[line][:,1:-5])[:,1]-dataset[line][:,-4])
#         result = np.append(result, coefs)
        i += 1
#     return result, sigmas
    return result

# %%
def analyze_coefs(coefs):
    for value in range(coefs.shape[1]):
        print('Characteristic {}:'.format(value))
        for feature_num in range(coefs.shape[2]):
            print('\tFeature {:d}:\n\t\tMean: {:.3f}\n\t\tRange: {:.3f} - {:.3f}\n\t\tMSE: {:.3f}\n\t\t% of outliers: {:.2f}'.format(feature_num+1, 
                                                                                                  coefs[:,value,feature_num].mean(), 
                                                                                                  coefs[:,value,feature_num].min(), 
                                                                                                  coefs[:,value,feature_num].max(), 
                                                                                                  coefs[:,value,feature_num].std() ,
                                                                                                  coefs[:,value,feature_num][(coefs[:,value,feature_num]>3*coefs[:,value,feature_num].std()) | (coefs[:,value,feature_num]<-3*coefs[:,value,feature_num].std())].size  /B                ))

# %%
B=5000

# %%
coefs = train_B_regressions(data2, B)

analyze_coefs(coefs)
# Out:
# Characteristic 0:
# 	Feature 1:
# 		Mean: 0.310
# 		Range: -90.158 - 6.731
# 		MSE: 1.376
# 		% of outliers: 0.00
# 	Feature 2:
# 		Mean: -0.015
# 		Range: -18.534 - 2.141
# 		MSE: 0.378
# 		% of outliers: 0.00
# 	Feature 3:
# 		Mean: -0.091
# 		Range: -2.827 - 46.249
# 		MSE: 0.780
# 		% of outliers: 0.00
# 	Feature 4:
# 		Mean: 0.572
# 		Range: -3.943 - 50.093
# 		MSE: 0.845
# 		% of outliers: 0.00
# 	Feature 5:
# 		Mean: -0.277
# 		Range: -67.025 - 4.914
# 		MSE: 1.016
# 		% of outliers: 0.00
# 	Feature 6:
# 		Mean: 0.224
# 		Range: -52.125 - 5.521
# 		MSE: 0.912
# 		% of outliers: 0.00
# 	Feature 7:
# 		Mean: -0.353
# 		Range: -6.091 - 187.782
# 		MSE: 2.718
# 		% of outliers: 0.00
# 	Feature 8:
# 		Mean: -0.109
# 		Range: -160.782 - 4.243
# 		MSE: 2.306
# 		% of outliers: 0.00
# 	Feature 9:
# 		Mean: -0.031
# 		Range: -41.019 - 4.496
# 		MSE: 0.709
# 		% of outliers: 0.00
# 	Feature 10:
# 		Mean: -0.160
# 		Range: -10.958 - 140.226
# 		MSE: 2.025
# 		% of outliers: 0.00
# 	Feature 11:
# 		Mean: 0.373
# 		Range: -5.498 - 45.162
# 		MSE: 0.766
# 		% of outliers: 0.00
# 	Feature 12:
# 		Mean: 0.023
# 		Range: -155.149 - 7.373
# 		MSE: 2.235
# 		% of outliers: 0.00
# 	Feature 13:
# 		Mean: 0.131
# 		Range: -3.521 - 40.389
# 		MSE: 0.722
# 		% of outliers: 0.00
# 	Feature 14:
# 		Mean: -0.019
# 		Range: -6.159 - 44.491
# 		MSE: 0.723
# 		% of outliers: 0.00
# 	Feature 15:
# 		Mean: -0.418
# 		Range: -2.696 - 33.225
# 		MSE: 0.569
# 		% of outliers: 0.00
# 	Feature 16:
# 		Mean: 0.199
# 		Range: -2.923 - 33.183
# 		MSE: 0.524
# 		% of outliers: 0.00
# 	Feature 17:
# 		Mean: 0.307
# 		Range: -77.332 - 4.462
# 		MSE: 1.137
# 		% of outliers: 0.00
# 	Feature 18:
# 		Mean: -0.070
# 		Range: -15.264 - 3.397
# 		MSE: 0.371
# 		% of outliers: 0.01
# 	Feature 19:
# 		Mean: -0.202
# 		Range: -4.362 - 9.020
# 		MSE: 0.335
# 		% of outliers: 0.01
# 	Feature 20:
# 		Mean: -0.142
# 		Range: -2.668 - 43.944
# 		MSE: 0.699
# 		% of outliers: 0.00
# 	Feature 21:
# 		Mean: 0.337
# 		Range: -40.723 - 4.398
# 		MSE: 0.668
# 		% of outliers: 0.00
# 	Feature 22:
# 		Mean: -0.016
# 		Range: -2.518 - 5.154
# 		MSE: 0.271
# 		% of outliers: 0.01
# 	Feature 23:
# 		Mean: 0.340
# 		Range: -52.517 - 2.367
# 		MSE: 0.781
# 		% of outliers: 0.00
# 	Feature 24:
# 		Mean: -0.229
# 		Range: -5.416 - 66.662
# 		MSE: 0.993
# 		% of outliers: 0.00
# 	Feature 25:
# 		Mean: 0.192
# 		Range: -31.697 - 6.598
# 		MSE: 0.562
# 		% of outliers: 0.00
# 	Feature 26:
# 		Mean: 0.045
# 		Range: -3.322 - 28.059
# 		MSE: 0.500
# 		% of outliers: 0.00
# 	Feature 27:
# 		Mean: -0.025
# 		Range: -9.953 - 4.327
# 		MSE: 0.361
# 		% of outliers: 0.01
# 	Feature 28:
# 		Mean: -0.150
# 		Range: -10.204 - 1.567
# 		MSE: 0.277
# 		% of outliers: 0.01
# Characteristic 1:
# 	Feature 1:
# 		Mean: -0.020
# 		Range: -22.794 - 19.347
# 		MSE: 0.785
# 		% of outliers: 0.02
# 	Feature 2:
# 		Mean: 0.106
# 		Range: -2.316 - 7.344
# 		MSE: 0.365
# 		% of outliers: 0.01
# 	Feature 3:
# 		Mean: -0.111
# 		Range: -11.112 - 4.092
# 		MSE: 0.570
# 		% of outliers: 0.01
# 	Feature 4:
# 		Mean: 0.233
# 		Range: -12.101 - 20.553
# 		MSE: 0.702
# 		% of outliers: 0.01
# 	Feature 5:
# 		Mean: 0.055
# 		Range: -4.327 - 16.975
# 		MSE: 0.604
# 		% of outliers: 0.01
# 	Feature 6:
# 		Mean: 0.469
# 		Range: -9.308 - 13.944
# 		MSE: 0.673
# 		% of outliers: 0.02
# 	Feature 7:
# 		Mean: 0.386
# 		Range: -39.609 - 18.860
# 		MSE: 0.909
# 		% of outliers: 0.01
# 	Feature 8:
# 		Mean: -0.396
# 		Range: -19.528 - 37.000
# 		MSE: 0.778
# 		% of outliers: 0.01
# 	Feature 9:
# 		Mean: -0.064
# 		Range: -7.186 - 9.497
# 		MSE: 0.537
# 		% of outliers: 0.02
# 	Feature 10:
# 		Mean: -0.046
# 		Range: -32.394 - 8.268
# 		MSE: 0.728
# 		% of outliers: 0.01
# 	Feature 11:
# 		Mean: 0.191
# 		Range: -11.105 - 15.539
# 		MSE: 0.606
# 		% of outliers: 0.01
# 	Feature 12:
# 		Mean: 0.053
# 		Range: -6.141 - 36.402
# 		MSE: 0.765
# 		% of outliers: 0.01
# 	Feature 13:
# 		Mean: 0.011
# 		Range: -11.260 - 16.207
# 		MSE: 0.639
# 		% of outliers: 0.01
# 	Feature 14:
# 		Mean: 0.185
# 		Range: -27.721 - 4.523
# 		MSE: 0.592
# 		% of outliers: 0.01
# 	Feature 15:
# 		Mean: -0.373
# 		Range: -8.736 - 2.328
# 		MSE: 0.455
# 		% of outliers: 0.02
# 	Feature 16:
# 		Mean: 0.187
# 		Range: -7.805 - 4.188
# 		MSE: 0.335
# 		% of outliers: 0.02
# 	Feature 17:
# 		Mean: 0.210
# 		Range: -2.272 - 17.640
# 		MSE: 0.438
# 		% of outliers: 0.01
# 	Feature 18:
# 		Mean: 0.020
# 		Range: -3.803 - 2.389
# 		MSE: 0.362
# 		% of outliers: 0.02
# 	Feature 19:
# 		Mean: -0.346
# 		Range: -4.944 - 2.516
# 		MSE: 0.426
# 		% of outliers: 0.02
# 	Feature 20:
# 		Mean: -0.153
# 		Range: -10.364 - 3.806
# 		MSE: 0.475
# 		% of outliers: 0.01
# 	Feature 21:
# 		Mean: 0.338
# 		Range: -2.698 - 10.388
# 		MSE: 0.452
# 		% of outliers: 0.02
# 	Feature 22:
# 		Mean: 0.192
# 		Range: -8.964 - 3.899
# 		MSE: 0.376
# 		% of outliers: 0.01
# 	Feature 23:
# 		Mean: -0.113
# 		Range: -8.728 - 11.330
# 		MSE: 0.354
# 		% of outliers: 0.01
# 	Feature 24:
# 		Mean: -0.025
# 		Range: -17.482 - 3.786
# 		MSE: 0.490
# 		% of outliers: 0.01
# 	Feature 25:
# 		Mean: 0.122
# 		Range: -3.508 - 10.460
# 		MSE: 0.495
# 		% of outliers: 0.01
# 	Feature 26:
# 		Mean: 0.244
# 		Range: -5.196 - 10.641
# 		MSE: 0.462
# 		% of outliers: 0.02
# 	Feature 27:
# 		Mean: -0.293
# 		Range: -10.776 - 7.172
# 		MSE: 0.489
# 		% of outliers: 0.02
# 	Feature 28:
# 		Mean: -0.210
# 		Range: -3.437 - 2.266
# 		MSE: 0.295
# 		% of outliers: 0.02
# Characteristic 2:
# 	Feature 1:
# 		Mean: 0.037
# 		Range: -2.654 - 2.445
# 		MSE: 0.150
# 		% of outliers: 0.02
# 	Feature 2:
# 		Mean: 0.035
# 		Range: -0.612 - 1.066
# 		MSE: 0.068
# 		% of outliers: 0.01
# 	Feature 3:
# 		Mean: 0.055
# 		Range: -4.578 - 1.426
# 		MSE: 0.122
# 		% of outliers: 0.01
# 	Feature 4:
# 		Mean: 0.083
# 		Range: -1.835 - 2.439
# 		MSE: 0.127
# 		% of outliers: 0.02
# 	Feature 5:
# 		Mean: 0.101
# 		Range: -1.895 - 1.159
# 		MSE: 0.098
# 		% of outliers: 0.02
# 	Feature 6:
# 		Mean: 0.007
# 		Range: -3.393 - 5.793
# 		MSE: 0.159
# 		% of outliers: 0.01
# 	Feature 7:
# 		Mean: 0.170
# 		Range: -4.486 - 4.352
# 		MSE: 0.177
# 		% of outliers: 0.02
# 	Feature 8:
# 		Mean: 0.133
# 		Range: -2.345 - 2.766
# 		MSE: 0.117
# 		% of outliers: 0.02
# 	Feature 9:
# 		Mean: 0.068
# 		Range: -1.581 - 1.731
# 		MSE: 0.106
# 		% of outliers: 0.02
# 	Feature 10:
# 		Mean: 0.053
# 		Range: -2.177 - 3.891
# 		MSE: 0.117
# 		% of outliers: 0.01
# 	Feature 11:
# 		Mean: 0.134
# 		Range: -0.981 - 2.557
# 		MSE: 0.116
# 		% of outliers: 0.02
# 	Feature 12:
# 		Mean: 0.118
# 		Range: -2.502 - 2.625
# 		MSE: 0.126
# 		% of outliers: 0.03
# 	Feature 13:
# 		Mean: 0.018
# 		Range: -2.163 - 1.766
# 		MSE: 0.125
# 		% of outliers: 0.01
# 	Feature 14:
# 		Mean: 0.053
# 		Range: -0.727 - 2.272
# 		MSE: 0.095
# 		% of outliers: 0.01
# 	Feature 15:
# 		Mean: 0.076
# 		Range: -0.885 - 1.172
# 		MSE: 0.083
# 		% of outliers: 0.02
# 	Feature 16:
# 		Mean: -0.003
# 		Range: -0.723 - 1.155
# 		MSE: 0.062
# 		% of outliers: 0.02
# 	Feature 17:
# 		Mean: -0.043
# 		Range: -1.472 - 1.138
# 		MSE: 0.080
# 		% of outliers: 0.02
# 	Feature 18:
# 		Mean: 0.002
# 		Range: -1.386 - 0.636
# 		MSE: 0.078
# 		% of outliers: 0.01
# 	Feature 19:
# 		Mean: 0.048
# 		Range: -0.637 - 1.623
# 		MSE: 0.083
# 		% of outliers: 0.02
# 	Feature 20:
# 		Mean: 0.015
# 		Range: -0.997 - 2.402
# 		MSE: 0.091
# 		% of outliers: 0.01
# 	Feature 21:
# 		Mean: -0.016
# 		Range: -2.574 - 3.302
# 		MSE: 0.101
# 		% of outliers: 0.01
# 	Feature 22:
# 		Mean: -0.037
# 		Range: -1.668 - 1.003
# 		MSE: 0.077
# 		% of outliers: 0.01
# 	Feature 23:
# 		Mean: 0.005
# 		Range: -1.903 - 0.906
# 		MSE: 0.067
# 		% of outliers: 0.01
# 	Feature 24:
# 		Mean: 0.033
# 		Range: -0.990 - 1.857
# 		MSE: 0.079
# 		% of outliers: 0.01
# 	Feature 25:
# 		Mean: -0.065
# 		Range: -2.282 - 1.051
# 		MSE: 0.102
# 		% of outliers: 0.02
# 	Feature 26:
# 		Mean: 0.001
# 		Range: -0.829 - 0.827
# 		MSE: 0.083
# 		% of outliers: 0.02
# 	Feature 27:
# 		Mean: 0.002
# 		Range: -1.394 - 1.433
# 		MSE: 0.094
# 		% of outliers: 0.01
# 	Feature 28:
# 		Mean: -0.022
# 		Range: -0.822 - 0.961
# 		MSE: 0.062
# 		% of outliers: 0.02
# Characteristic 3:
# 	Feature 1:
# 		Mean: -0.023
# 		Range: -3.780 - 10.756
# 		MSE: 0.180
# 		% of outliers: 0.00
# 	Feature 2:
# 		Mean: -0.000
# 		Range: -0.369 - 2.158
# 		MSE: 0.052
# 		% of outliers: 0.01
# 	Feature 3:
# 		Mean: 0.029
# 		Range: -5.564 - 0.720
# 		MSE: 0.106
# 		% of outliers: 0.00
# 	Feature 4:
# 		Mean: 0.029
# 		Range: -5.897 - 3.262
# 		MSE: 0.116
# 		% of outliers: 0.00
# 	Feature 5:
# 		Mean: 0.045
# 		Range: -1.065 - 8.052
# 		MSE: 0.129
# 		% of outliers: 0.00
# 	Feature 6:
# 		Mean: 0.047
# 		Range: -1.664 - 6.542
# 		MSE: 0.129
# 		% of outliers: 0.00
# 	Feature 7:
# 		Mean: -0.021
# 		Range: -22.578 - 3.082
# 		MSE: 0.333
# 		% of outliers: 0.00
# 	Feature 8:
# 		Mean: 0.065
# 		Range: -3.117 - 19.370
# 		MSE: 0.283
# 		% of outliers: 0.00
# 	Feature 9:
# 		Mean: 0.039
# 		Range: -0.907 - 4.888
# 		MSE: 0.092
# 		% of outliers: 0.00
# 	Feature 10:
# 		Mean: 0.024
# 		Range: -16.767 - 2.267
# 		MSE: 0.249
# 		% of outliers: 0.00
# 	Feature 11:
# 		Mean: -0.010
# 		Range: -5.344 - 2.602
# 		MSE: 0.107
# 		% of outliers: 0.00
# 	Feature 12:
# 		Mean: 0.000
# 		Range: -1.581 - 18.543
# 		MSE: 0.273
# 		% of outliers: 0.00
# 	Feature 13:
# 		Mean: -0.063
# 		Range: -5.007 - 2.515
# 		MSE: 0.105
# 		% of outliers: 0.01
# 	Feature 14:
# 		Mean: 0.039
# 		Range: -5.236 - 1.289
# 		MSE: 0.112
# 		% of outliers: 0.00
# 	Feature 15:
# 		Mean: -0.029
# 		Range: -4.132 - 0.404
# 		MSE: 0.078
# 		% of outliers: 0.00
# 	Feature 16:
# 		Mean: 0.023
# 		Range: -3.901 - 0.715
# 		MSE: 0.067
# 		% of outliers: 0.00
# 	Feature 17:
# 		Mean: -0.044
# 		Range: -0.600 - 9.226
# 		MSE: 0.138
# 		% of outliers: 0.00
# 	Feature 18:
# 		Mean: 0.034
# 		Range: -0.707 - 1.839
# 		MSE: 0.051
# 		% of outliers: 0.01
# 	Feature 19:
# 		Mean: 0.026
# 		Range: -1.062 - 0.878
# 		MSE: 0.047
# 		% of outliers: 0.02
# 	Feature 20:
# 		Mean: 0.030
# 		Range: -5.228 - 0.467
# 		MSE: 0.090
# 		% of outliers: 0.00
# 	Feature 21:
# 		Mean: 0.043
# 		Range: -0.601 - 5.051
# 		MSE: 0.092
# 		% of outliers: 0.00
# 	Feature 22:
# 		Mean: -0.048
# 		Range: -1.632 - 0.245
# 		MSE: 0.050
# 		% of outliers: 0.01
# 	Feature 23:
# 		Mean: 0.021
# 		Range: -1.453 - 6.322
# 		MSE: 0.098
# 		% of outliers: 0.00
# 	Feature 24:
# 		Mean: 0.012
# 		Range: -8.015 - 1.092
# 		MSE: 0.123
# 		% of outliers: 0.00
# 	Feature 25:
# 		Mean: -0.051
# 		Range: -1.366 - 3.766
# 		MSE: 0.080
# 		% of outliers: 0.01
# 	Feature 26:
# 		Mean: 0.015
# 		Range: -3.268 - 1.744
# 		MSE: 0.070
# 		% of outliers: 0.01
# 	Feature 27:
# 		Mean: 0.010
# 		Range: -1.706 - 0.687
# 		MSE: 0.058
# 		% of outliers: 0.01
# 	Feature 28:
# 		Mean: 0.001
# 		Range: -0.502 - 1.237
# 		MSE: 0.040
# 		% of outliers: 0.01
# Characteristic 4:
# 	Feature 1:
# 		Mean: 0.107
# 		Range: -22.363 - 3.247
# 		MSE: 0.427
# 		% of outliers: 0.01
# 	Feature 2:
# 		Mean: 0.037
# 		Range: -4.922 - 1.761
# 		MSE: 0.168
# 		% of outliers: 0.01
# 	Feature 3:
# 		Mean: -0.041
# 		Range: -1.727 - 11.584
# 		MSE: 0.279
# 		% of outliers: 0.01
# 	Feature 4:
# 		Mean: 0.303
# 		Range: -2.177 - 12.082
# 		MSE: 0.311
# 		% of outliers: 0.02
# 	Feature 5:
# 		Mean: -0.038
# 		Range: -15.828 - 2.902
# 		MSE: 0.299
# 		% of outliers: 0.00
# 	Feature 6:
# 		Mean: 0.231
# 		Range: -12.071 - 2.485
# 		MSE: 0.340
# 		% of outliers: 0.01
# 	Feature 7:
# 		Mean: 0.038
# 		Range: -2.461 - 46.811
# 		MSE: 0.721
# 		% of outliers: 0.00
# 	Feature 8:
# 		Mean: -0.099
# 		Range: -39.075 - 1.501
# 		MSE: 0.597
# 		% of outliers: 0.00
# 	Feature 9:
# 		Mean: 0.001
# 		Range: -9.939 - 1.783
# 		MSE: 0.271
# 		% of outliers: 0.01
# 	Feature 10:
# 		Mean: -0.049
# 		Range: -4.106 - 34.144
# 		MSE: 0.530
# 		% of outliers: 0.00
# 	Feature 11:
# 		Mean: 0.226
# 		Range: -1.655 - 10.864
# 		MSE: 0.291
# 		% of outliers: 0.01
# 	Feature 12:
# 		Mean: 0.062
# 		Range: -37.548 - 3.157
# 		MSE: 0.582
# 		% of outliers: 0.00
# 	Feature 13:
# 		Mean: 0.038
# 		Range: -1.795 - 9.223
# 		MSE: 0.281
# 		% of outliers: 0.01
# 	Feature 14:
# 		Mean: 0.074
# 		Range: -6.453 - 10.960
# 		MSE: 0.254
# 		% of outliers: 0.00
# 	Feature 15:
# 		Mean: -0.243
# 		Range: -1.550 - 7.742
# 		MSE: 0.229
# 		% of outliers: 0.02
# 	Feature 16:
# 		Mean: 0.130
# 		Range: -0.827 - 8.046
# 		MSE: 0.179
# 		% of outliers: 0.01
# 	Feature 17:
# 		Mean: 0.148
# 		Range: -18.919 - 2.274
# 		MSE: 0.317
# 		% of outliers: 0.00
# 	Feature 18:
# 		Mean: -0.009
# 		Range: -4.095 - 1.103
# 		MSE: 0.177
# 		% of outliers: 0.01
# 	Feature 19:
# 		Mean: -0.154
# 		Range: -1.305 - 2.151
# 		MSE: 0.196
# 		% of outliers: 0.02
# 	Feature 20:
# 		Mean: -0.084
# 		Range: -1.750 - 10.607
# 		MSE: 0.246
# 		% of outliers: 0.01
# 	Feature 21:
# 		Mean: 0.225
# 		Range: -9.585 - 2.237
# 		MSE: 0.235
# 		% of outliers: 0.01
# 	Feature 22:
# 		Mean: 0.029
# 		Range: -1.951 - 1.522
# 		MSE: 0.157
# 		% of outliers: 0.01
# 	Feature 23:
# 		Mean: 0.092
# 		Range: -12.989 - 0.936
# 		MSE: 0.228
# 		% of outliers: 0.00
# 	Feature 24:
# 		Mean: -0.075
# 		Range: -1.139 - 15.607
# 		MSE: 0.289
# 		% of outliers: 0.00
# 	Feature 25:
# 		Mean: 0.072
# 		Range: -7.394 - 2.391
# 		MSE: 0.224
# 		% of outliers: 0.01
# 	Feature 26:
# 		Mean: 0.093
# 		Range: -1.609 - 7.239
# 		MSE: 0.217
# 		% of outliers: 0.01
# 	Feature 27:
# 		Mean: -0.094
# 		Range: -2.575 - 1.151
# 		MSE: 0.211
# 		% of outliers: 0.01
# 	Feature 28:
# 		Mean: -0.122
# 		Range: -2.526 - 0.842
# 		MSE: 0.134
# 		% of outliers: 0.02

# %%
coef_no = 11

print(coefs[:,0,coef_no].mean())

print(coefs[:,0,coef_no].max())

print(coefs[:,0,coef_no].std()/coefs[:,0,coef_no].max())
# Out:
# 0.0570144605467
# 3.98976027338
# 0.104297091816

# %%
regr = linear_model.LinearRegression()

regr.fit(data2[:,1:-5], data2[:,-5:])

# %%
t_coef = np.insert(regr.coef_,0,regr.intercept_,axis=1)

t_coef.shape

# %%
np.std(regr.predict(data2[:,1:-5])[:,0]-data2[:,-5])
# Out:
# 0.41803352816107664

# %%
def perdict(x, coef):
    return x.dot(coef)

# %%
t_no = 0
t_data_x = np.insert(data2[:,1:-5].copy(), 0 ,1, axis=1)
t_data_y = data2[:,t_no].copy()

# %%
t_data_x.shape
# Out:
# (40, 29)

# %%
np.std(perdict(t_data_x, t_coef[0])-data2[:,-4])
# Out:
# 1.7312471141369301

# %%
mdsl.cross_va
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-9e4caaeb57e7> in <module>()
# ----> 1 mdsl.cross_calidate()
#
# AttributeError: module 'sklearn.model_selection' has no attribute 'cross_calidate'

# %%
skle
